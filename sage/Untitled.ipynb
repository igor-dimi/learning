# %%
3 + 3
# Out:
# 6

# %%
sqrt(300)
# Out:
# 10*sqrt(3)

# %%
N(%)
# Out:
#   Cell In[3], line 1
#     N(%)
#       ^
# SyntaxError: invalid syntax

# %%
N([%])
# Out:
#   Cell In[4], line 1
#     N([%])
#        ^
# SyntaxError: invalid syntax

# %%
N(sqrt(100))
# Out:
# 10.0000000000000

# %%
plot(x^2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(x^3 - x)
# Out:
# Graphics object consisting of 1 graphics primitive
